# %%
text = "Python is easy to learn"

print("Original string:", text)
print("String in reverse:", text[::-1])
print("Words in reverse:", " ".join(text.split()[::-1]))
# Out:
# Original string: Python is easy to learn
# String in reverse: nrael ot ysae si nohtyP
# Words in reverse: learn to easy is Python
