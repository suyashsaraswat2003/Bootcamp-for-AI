# %%
import pandas as pd

data = {
    "Student_ID": [
        "ST001", "ST002", "ST003", "ST004", "ST005",
        "ST006", "ST007", "ST008", "ST009", "ST010",
        "ST011", "ST012", "ST013", "ST014", "ST015",
        "ST005"
    ],

    "Name": [
        " Suyash Saraswat ", "rahul sharma", "PRIYA SINGH",
        " Amit Kumar!!", "Neha Verma ", " rohan mehta",
        "Anjali Gupta", "VIKAS YADAV", " Pooja Shah",
        "Karan Patel ", "Sneha Rao", " ARJUN REDDY",
        "Meena Joshi", "Ravi Kumar", " Simran Kaur ",
        "Neha Verma "
    ],

    "Age": [
        22, 21, None, 23, "twenty", 22,
        21, 24, 22, None, 23, 21,
        22, 150, 21, 22
    ],

    "Email": [
        "suyash@gmail.com",
        "rahul@gmail.com ",
        "PRIYA@GMAIL.COM",
        "amit@gmail.com",
        "neha@gmail.com",
        "rohan@gmail.com",
        "anjali@gmail.com",
        "vikas@gmail.com",
        "pooja@gmail.com",
        "karan@gmail.com",
        "sneha@gmail.com",
        "arjun@gmail.com",
        "meena@gmail.com",
        "ravi@gmail",
        "simran@gmail.com",
        "neha@gmail.com"
    ],

    "City": [
        " Delhi", "mumbai ", "DELHI", "Bangalore",
        " Mumbai", "chennai", "Delhi ", " MUMBAI",
        "Bangalore ", "Delhi", "CHENNAI",
        " Hyderabad ", "Delhi", "Mumbai",
        "mumbai ", " Mumbai"
    ],

    "Marks": [
        "85", "90", "78", "95", "invalid",
        "88", "92", "105", "76", "89",
        None, "94", "81", "-10", "87", "88"
    ]
}

df = pd.DataFrame(data)

df.to_csv("student_data.csv", index=False)

print(df)
# Out:
#    Student_ID               Name     Age             Email         City  \
# 0       ST001   Suyash Saraswat       22  suyash@gmail.com        Delhi
# 1       ST002       rahul sharma      21  rahul@gmail.com       mumbai
# 2       ST003        PRIYA SINGH    None   PRIYA@GMAIL.COM        DELHI
# 3       ST004       Amit Kumar!!      23    amit@gmail.com    Bangalore
# 4       ST005        Neha Verma   twenty    neha@gmail.com       Mumbai
# 5       ST006        rohan mehta      22   rohan@gmail.com      chennai
# 6       ST007       Anjali Gupta      21  anjali@gmail.com       Delhi
# 7       ST008        VIKAS YADAV      24   vikas@gmail.com       MUMBAI
# 8       ST009         Pooja Shah      22   pooja@gmail.com   Bangalore
# 9       ST010       Karan Patel     None   karan@gmail.com        Delhi
# 10      ST011          Sneha Rao      23   sneha@gmail.com      CHENNAI
# 11      ST012        ARJUN REDDY      21   arjun@gmail.com   Hyderabad
# ...
