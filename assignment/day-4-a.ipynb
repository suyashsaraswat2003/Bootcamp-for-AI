# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\suyas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\suyas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\suyas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text = """
One of my favorite hobbies is reading manga and fanfiction novels. I enjoy reading different
kinds of stories because they allow me to explore new worlds, characters, and ideas. Manga is
especially interesting to me because it combines storytelling with visual art, making the
characters and events easier to imagine. I also enjoy fanfiction novels because they take
familiar characters or fictional worlds and present them in new situations and stories.
Sometimes, fanfiction explores alternative endings, different character relationships, or
completely new storylines that are not present in the original work. Reading these stories
is a great way for me to relax during my free time. It also helps improve my imagination and
creativity because I often think about how a story might continue or how I would change
certain events. Manga and fanfiction introduce me to different writing styles, cultures,
and perspectives. They also help me develop my vocabulary and reading skills naturally.
Another reason I enjoy this hobby is that there are many genres to choose from, including
action, fantasy, science fiction, comedy, mystery, and adventure. Overall, reading manga
and fanfiction is both an enjoyable form of entertainment and a way for me to explore my
creativity and imagination.
"""

print(text)
# Out:
# One of my favorite hobbies is reading manga and fanfiction novels. I enjoy reading different
# kinds of stories because they allow me to explore new worlds, characters, and ideas. Manga is
# especially interesting to me because it combines storytelling with visual art, making the
# characters and events easier to imagine. I also enjoy fanfiction novels because they take
# familiar characters or fictional worlds and present them in new situations and stories.
# Sometimes, fanfiction explores alternative endings, different character relationships, or
# completely new storylines that are not present in the original work. Reading these stories
# is a great way for me to relax during my free time. It also helps improve my imagination and
# creativity because I often think about how a story might continue or how I would change
# certain events. Manga and fanfiction introduce me to different writing styles, cultures,
# ...

# %%
words = word_tokenize(text.lower())

print(words)
# Out:
# ['one', 'of', 'my', 'favorite', 'hobbies', 'is', 'reading', 'manga', 'and', 'fanfiction', 'novels', '.', 'i', 'enjoy', 'reading', 'different', 'kinds', 'of', 'stories', 'because', 'they', 'allow', 'me', 'to', 'explore', 'new', 'worlds', ',', 'characters', ',', 'and', 'ideas', '.', 'manga', 'is', 'especially', 'interesting', 'to', 'me', 'because', 'it', 'combines', 'storytelling', 'with', 'visual', 'art', ',', 'making', 'the', 'characters', 'and', 'events', 'easier', 'to', 'imagine', '.', 'i', 'also', 'enjoy', 'fanfiction', 'novels', 'because', 'they', 'take', 'familiar', 'characters', 'or', 'fictional', 'worlds', 'and', 'present', 'them', 'in', 'new', 'situations', 'and', 'stories', '.', 'sometimes', ',', 'fanfiction', 'explores', 'alternative', 'endings', ',', 'different', 'character', 'relationships', ',', 'or', 'completely', 'new', 'storylines', 'that', 'are', 'not', 'present', 'in', 'the', 'original', 'work', '.', 'reading', 'these', 'stories', 'is', 'a', 'great', 'way', 'for', '
# ...

# %%
stop_words = set(stopwords.words("english"))

filtered_words = [
    word for word in words
    if word.isalpha() and word not in stop_words
]

print(filtered_words)
# Out:
# ['one', 'favorite', 'hobbies', 'reading', 'manga', 'fanfiction', 'novels', 'enjoy', 'reading', 'different', 'kinds', 'stories', 'allow', 'explore', 'new', 'worlds', 'characters', 'ideas', 'manga', 'especially', 'interesting', 'combines', 'storytelling', 'visual', 'art', 'making', 'characters', 'events', 'easier', 'imagine', 'also', 'enjoy', 'fanfiction', 'novels', 'take', 'familiar', 'characters', 'fictional', 'worlds', 'present', 'new', 'situations', 'stories', 'sometimes', 'fanfiction', 'explores', 'alternative', 'endings', 'different', 'character', 'relationships', 'completely', 'new', 'storylines', 'present', 'original', 'work', 'reading', 'stories', 'great', 'way', 'relax', 'free', 'time', 'also', 'helps', 'improve', 'imagination', 'creativity', 'often', 'think', 'story', 'might', 'continue', 'would', 'change', 'certain', 'events', 'manga', 'fanfiction', 'introduce', 'different', 'writing', 'styles', 'cultures', 'perspectives', 'also', 'help', 'develop', 'vocabulary', 'reading',
# ...

# %%
word_freq = Counter(filtered_words)

print(word_freq)
# Out:
# Counter({'reading': 5, 'fanfiction': 5, 'manga': 4, 'enjoy': 3, 'different': 3, 'stories': 3, 'new': 3, 'characters': 3, 'also': 3, 'novels': 2, 'explore': 2, 'worlds': 2, 'events': 2, 'present': 2, 'way': 2, 'imagination': 2, 'creativity': 2, 'one': 1, 'favorite': 1, 'hobbies': 1, 'kinds': 1, 'allow': 1, 'ideas': 1, 'especially': 1, 'interesting': 1, 'combines': 1, 'storytelling': 1, 'visual': 1, 'art': 1, 'making': 1, 'easier': 1, 'imagine': 1, 'take': 1, 'familiar': 1, 'fictional': 1, 'situations': 1, 'sometimes': 1, 'explores': 1, 'alternative': 1, 'endings': 1, 'character': 1, 'relationships': 1, 'completely': 1, 'storylines': 1, 'original': 1, 'work': 1, 'great': 1, 'relax': 1, 'free': 1, 'time': 1, 'helps': 1, 'improve': 1, 'often': 1, 'think': 1, 'story': 1, 'might': 1, 'continue': 1, 'would': 1, 'change': 1, 'certain': 1, 'introduce': 1, 'writing': 1, 'styles': 1, 'cultures': 1, 'perspectives': 1, 'help': 1, 'develop': 1, 'vocabulary': 1, 'skills': 1, 'naturally': 1, 'anothe
# ...

# %%
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color="white"
).generate_from_frequencies(word_freq)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")

plt.savefig(
    "Manga_Fanfiction_WordCloud.jpg",
    format="jpg",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
