# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
time = np.linspace(0, 10, 500)

amplitude1 = np.sin(2 * np.pi * time)
amplitude2 = np.exp(-0.5 * time) * np.sin(2 * np.pi * time)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))

ax1.plot(time, amplitude1, linewidth=2, label="Undamped Harmonic Motion")
ax1.set_title("Harmonic Response of Structure")
ax1.set_xlabel("Time (seconds)")
ax1.set_ylabel("Displacement (mm)")
ax1.grid(True)
ax1.legend()

ax2.plot(time, amplitude2, linewidth=2, label="Damped Harmonic Motion")
ax2.set_title("Damped Harmonic Response of Structure")
ax2.set_xlabel("Time (seconds)")
ax2.set_ylabel("Displacement (mm)")
ax2.grid(True)
ax2.legend()
plt.tight_layout()
plt.show()
