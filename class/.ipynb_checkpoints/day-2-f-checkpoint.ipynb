# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(42)

n_students = 100

data = {
    "StudentID": np.arange(1, n_students + 1),
    "G1": np.random.randint(0, 20, n_students),
    "G2": np.random.randint(0, 20, n_students),
    "G3": np.random.randint(0, 20, n_students),
    "Mjob": np.random.choice(['teacher', 'health', 'services', 'at_home', 'other'], n_students),
    "Fjob": np.random.choice(['teacher', 'health', 'services', 'at_home', 'other'], n_students),
    "age": np.random.randint(15, 22, n_students),
    "address": np.random.choice(['urban', 'rural'], n_students),
    "studytime": np.random.randint(1, 5, n_students),
    "failures": np.random.randint(0, 4, n_students),
    "schoolsup": np.random.choice(['yes', 'no'], n_students),
    "famsup": np.random.choice(['yes', 'no'], n_students),
    "paid": np.random.choice(['yes', 'no'], n_students),
    "activities": np.random.choice(['yes', 'no'], n_students),
    "nursery": np.random.choice(['yes', 'no'], n_students),
    "higher": np.random.choice(['yes', 'no'], n_students),
    "internet": np.random.choice(['yes', 'no'], n_students)
}

df = pd.DataFrame(data)
df.to_csv("student_performance.csv", index=False)

print(df.head())
# Out:
#    StudentID  G1  G2  G3      Mjob     Fjob  age address  studytime  failures  \
# 0          1   6   2   2   teacher  at_home   21   rural          3         1
# 1          2  19  11  18    health  teacher   18   rural          1         1
# 2          3  14   7  19    health    other   20   urban          1         1
# 3          4  10   2   6  services   health   21   urban          3         1
# 4          5   7   0  19    health   health   18   rural          4         1
#
#   schoolsup famsup paid activities nursery higher internet
# 0        no    yes  yes        yes     yes    yes       no
# 1        no     no   no         no     yes     no       no
# 2       yes    yes  yes         no      no     no      yes
# 3       yes     no  yes         no     yes     no       no
# 4        no     no  yes         no     yes    yes      yes

# %%
df = pd.read_csv("student_performance.csv")

print(df.isnull().sum())

for column in df.select_dtypes(include='object').columns:
    df[column] = df[column].fillna(df[column].mode()[0])
# Out:
# StudentID     0
# G1            0
# G2            0
# G3            0
# Mjob          0
# Fjob          0
# age           0
# address       0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# dtype: int64
# C:\Users\suyas\AppData\Local\Temp\ipykernel_6728\1419698092.py:5: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for column in df.select_dtypes(include='object').columns:

# %%
print(df.describe())
print(df.dtypes)
# Out:
#         StudentID          G1          G2          G3         age  studytime  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.00000
# mean    50.500000    9.010000    8.710000    9.070000   18.180000    2.21000
# std     29.011492    5.535003    6.107282    6.629068    1.940426    1.06643
# min      1.000000    0.000000    0.000000    0.000000   15.000000    1.00000
# 25%     25.750000    4.750000    3.750000    2.000000   16.750000    1.00000
# 50%     50.500000    8.500000    8.000000    8.000000   18.000000    2.00000
# 75%     75.250000   14.000000   14.000000   15.000000   20.000000    3.00000
# max    100.000000   19.000000   19.000000   19.000000   21.000000    4.00000
#
#          failures
# count  100.000000
# mean     1.380000
# std      1.080404
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      3.000000
# StudentID     int64
# G1            int64
# G2            int64
# G3            int64
# Mjob            str
# Fjob            str
# age           int64
# address         str
# studytime     int64
# failures      int64
# schoolsup       str
# famsup          str
# paid            str
# activities      str
# nursery         str
# higher          str
# internet        str
# dtype: object

# %%
df[['G1', 'G2', 'G3']] = df[['G1', 'G2', 'G3']].apply(
    pd.to_numeric, errors='coerce'
)

df['average_score'] = df[['G1', 'G2', 'G3']].mean(axis=1)

print(df[['G1', 'G2', 'G3', 'average_score']].head())
# Out:
#    G1  G2  G3  average_score
# 0   6   2   2       3.333333
# 1  19  11  18      16.000000
# 2  14   7  19      13.333333
# 3  10   2   6       6.000000
# 4   7   0  19       8.666667

# %%
above_five_g3 = df[df['G3'] > 5]

print(above_five_g3)
# Out:
#     StudentID  G1  G2  G3      Mjob      Fjob  age address  studytime  \
# 1           2  19  11  18    health   teacher   18   rural          1
# 2           3  14   7  19    health     other   20   urban          1
# 3           4  10   2   6  services    health   21   urban          3
# 4           5   7   0  19    health    health   18   rural          4
# 5           6   6   2   8    health     other   17   urban          1
# ..        ...  ..  ..  ..       ...       ...  ...     ...        ...
# 90         91   6  15   8     other  services   16   urban          1
# 92         93   6   0  16     other   teacher   18   urban          2
# 93         94   8   8  13   teacher   at_home   19   urban          2
# 96         97   1   2  19   at_home   teacher   21   rural          3
# 99        100   4  18  17     other   teacher   19   rural          4
#
#     failures schoolsup famsup paid activities nursery higher internet  \
# 1          1        no     no   no         no     yes     no       no
# 2          1       yes    yes  yes         no      no     no      yes
# 3          1       yes     no  yes         no     yes     no       no
# 4          1        no     no  yes         no     yes    yes      yes
# 5          1       yes    yes   no         no      no    yes       no
# ..       ...       ...    ...  ...        ...     ...    ...      ...
# 90         1        no    yes  yes        yes     yes    yes       no
# 92         2       yes    yes  yes        yes     yes    yes      yes
# 93         0        no    yes   no        yes      no    yes      yes
# 96         2        no    yes  yes         no      no     no      yes
# 99         2       yes    yes  yes        yes      no     no      yes
#
#     average_score
# 1       16.000000
# 2       13.333333
# 3        6.000000
# 4        8.666667
# 5        5.333333
# ..            ...
# 90       9.666667
# 92       7.333333
# 93       9.666667
# 96       7.333333
# 99      13.000000
#
# [62 rows x 18 columns]

# %%
count_by_mjob = above_five_g3['Mjob'].value_counts()

print(count_by_mjob)
# Out:
# Mjob
# health      19
# teacher     14
# at_home     11
# other       10
# services     8
# Name: count, dtype: int64
