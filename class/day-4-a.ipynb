# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"C:\Users\suyas\Desktop\JupyterLab-setup\Bootcamp\class\Screenshot 2026-08-24 212754.png")
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape)
# Out:
# (275, 773, 3)

# %%
cv2.imshow("Photos",img)
cv2.waitKey(0)
# Out:
# -1

# %%
img_resize = cv2.resize(img,(400,256))
cv2.imshow("Photos", img_resize)
cv2.waitKey(0)
# Out:
# -1

# %%
img_flip = cv2.flip(img,0)
cv2.imshow("Photos", img_flip)
cv2.waitKey(0)
# Out:
# -1

# %%
img_crop =  img[100:300, 200:500]
cv2.imshow("Photos", img_crop)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cam = cv2.VideoCapture(0)
